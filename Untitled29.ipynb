# %%
import tensorflow

# %%
from tensorflow.keras.preprocessing import image

# %%
image.load_img('/content/jersy__cricket.jfif', target_size=(224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img = image.load_img('/content/jersy__cricket.jfif', target_size=(224,224))

# %%
image_array = image.img_to_array(img)

# %%
image_array
# Out:
# array([[[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        ...,
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]],
#
#        [[254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.],
#         ...,
#         [254., 254., 254.],
#         [254., 254., 254.],
#         [254., 254., 254.]]], dtype=float32)

# %%
image_array.shape
# Out:
# (224, 224, 3)

# %%
import numpy as np
expanded_img_array = np.expand_dims(image_array,axis=0)

# %%
print(expanded_img_array.shape)
# Out:
# (1, 224, 224, 3)

# %%
expanded_img_array
# Out:
# array([[[[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         ...,
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]]]], dtype=float32)

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
model = ResNet50(weights= 'imagenet', include_top=False,input_shape=(224,224,3))
model.trainable = False

model = tensorflow.keras.Sequential([model,GlobalAveragePooling2D()])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
preprocessed_img = preprocess_input(expanded_img_array)

print(preprocessed_img.shape)
# Out:
# (1, 224, 224, 3)

# %%
preprocessed_img
# Out:
# array([[[[150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          ...,
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ]],
#
#         [[150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          ...,
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ]],
#
#         [[150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          ...,
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ]],
#
#         ...,
#
#         [[150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          ...,
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ]],
#
#         [[150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          ...,
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ]],
#
#         [[150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          ...,
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ],
#          [150.061  , 137.22101, 130.32   ]]]], dtype=float32)

# %%
model.predict(preprocessed_img).shape
# Out:
# 1/1 [==============================] - 1s 1s/step
# (1, 2048)

# %%
model.predict(preprocessed_img).flatten()
# Out:
# 1/1 [==============================] - 0s 182ms/step
# array([0.0515601 , 6.2430563 , 0.15120919, ..., 0.        , 0.4625231 ,
#        0.685705  ], dtype=float32)

# %%
model.predict(preprocessed_img).flatten().shape
# Out:
# 1/1 [==============================] - 0s 194ms/step
# (2048,)

# %%
from numpy.linalg import norm
norm(model.predict(preprocessed_img).flatten())
# Out:
# 1/1 [==============================] - 0s 183ms/step
# 34.909077

# %%
model.predict(preprocessed_img).flatten()/norm(model.predict(preprocessed_img).flatten())
# Out:
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 175ms/step
# array([0.00147698, 0.17883763, 0.00433152, ..., 0.        , 0.01324936,
#        0.0196426 ], dtype=float32)
