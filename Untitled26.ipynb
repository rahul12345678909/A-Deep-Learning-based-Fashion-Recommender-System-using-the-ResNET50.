# %%
import tensorflow

# %%
from tensorflow.keras.preprocessing import image

# %%
image.load_img('/content/cricket pic.jfif', target_size=(224,224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img = image.load_img('/content/cricket pic.jfif', target_size=(224,224))

# %%
image_array = image.img_to_array(img)

# %%
image_array
# Out:
# array([[[182., 206., 148.],
#         [182., 206., 148.],
#         [183., 207., 149.],
#         ...,
#         [ 79.,  78.,  21.],
#         [ 73.,  51.,  12.],
#         [ 65.,  43.,   4.]],
#
#        [[182., 206., 148.],
#         [182., 206., 148.],
#         [183., 207., 149.],
#         ...,
#         [ 77.,  77.,  17.],
#         [ 75.,  53.,  14.],
#         [ 68.,  46.,   7.]],
#
#        [[182., 206., 148.],
#         [182., 206., 148.],
#         [183., 207., 149.],
#         ...,
#         [ 75.,  73.,  12.],
#         [ 78.,  56.,  15.],
#         [ 71.,  49.,   8.]],
#
#        ...,
#
#        [[ 37.,  44., 112.],
#         [ 39.,  48., 115.],
#         [ 43.,  57., 122.],
#         ...,
#         [ 65.,  77., 103.],
#         [ 66.,  76., 103.],
#         [ 66.,  76., 103.]],
#
#        [[ 39.,  46., 114.],
#         [ 40.,  49., 116.],
#         [ 43.,  57., 122.],
#         ...,
#         [ 66.,  78., 104.],
#         [ 67.,  77., 104.],
#         [ 67.,  77., 104.]],
#
#        [[ 40.,  47., 115.],
#         [ 41.,  50., 117.],
#         [ 43.,  57., 122.],
#         ...,
#         [ 67.,  79., 105.],
#         [ 68.,  78., 105.],
#         [ 68.,  78., 105.]]], dtype=float32)

# %%
image_array.shape
# Out:
# (224, 224, 3)

# %%
import numpy as np
expanded_img_array = np.expand_dims(image_array,axis=0)

# %%
print(expanded_img_array.shape)
# Out:
# (1, 224, 224, 3)

# %%
expanded_img_array
# Out:
# array([[[[182., 206., 148.],
#          [182., 206., 148.],
#          [183., 207., 149.],
#          ...,
#          [ 79.,  78.,  21.],
#          [ 73.,  51.,  12.],
#          [ 65.,  43.,   4.]],
#
#         [[182., 206., 148.],
#          [182., 206., 148.],
#          [183., 207., 149.],
#          ...,
#          [ 77.,  77.,  17.],
#          [ 75.,  53.,  14.],
#          [ 68.,  46.,   7.]],
#
#         [[182., 206., 148.],
#          [182., 206., 148.],
#          [183., 207., 149.],
#          ...,
#          [ 75.,  73.,  12.],
#          [ 78.,  56.,  15.],
#          [ 71.,  49.,   8.]],
#
#         ...,
#
#         [[ 37.,  44., 112.],
#          [ 39.,  48., 115.],
#          [ 43.,  57., 122.],
#          ...,
#          [ 65.,  77., 103.],
#          [ 66.,  76., 103.],
#          [ 66.,  76., 103.]],
#
#         [[ 39.,  46., 114.],
#          [ 40.,  49., 116.],
#          [ 43.,  57., 122.],
#          ...,
#          [ 66.,  78., 104.],
#          [ 67.,  77., 104.],
#          [ 67.,  77., 104.]],
#
#         [[ 40.,  47., 115.],
#          [ 41.,  50., 117.],
#          [ 43.,  57., 122.],
#          ...,
#          [ 67.,  79., 105.],
#          [ 68.,  78., 105.],
#          [ 68.,  78., 105.]]]], dtype=float32)

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import GlobalAveragePooling2D

# %%
model = ResNet50(weights= 'imagenet', include_top=False,input_shape=(224,224,3))
model.trainable = False


model = tensorflow.keras.Sequential([model,GlobalAveragePooling2D()])

# %%
preprocessed_img = preprocess_input(expanded_img_array)

print(preprocessed_img.shape)
# Out:
# (1, 224, 224, 3)

# %%
preprocessed_img
# Out:
# array([[[[ 4.4060997e+01,  8.9221001e+01,  5.8320000e+01],
#          [ 4.4060997e+01,  8.9221001e+01,  5.8320000e+01],
#          [ 4.5060997e+01,  9.0221001e+01,  5.9320000e+01],
#          ...,
#          [-8.2939003e+01, -3.8778999e+01, -4.4680000e+01],
#          [-9.1939003e+01, -6.5778999e+01, -5.0680000e+01],
#          [-9.9939003e+01, -7.3778999e+01, -5.8680000e+01]],
#
#         [[ 4.4060997e+01,  8.9221001e+01,  5.8320000e+01],
#          [ 4.4060997e+01,  8.9221001e+01,  5.8320000e+01],
#          [ 4.5060997e+01,  9.0221001e+01,  5.9320000e+01],
#          ...,
#          [-8.6939003e+01, -3.9778999e+01, -4.6680000e+01],
#          [-8.9939003e+01, -6.3778999e+01, -4.8680000e+01],
#          [-9.6939003e+01, -7.0778999e+01, -5.5680000e+01]],
#
#         [[ 4.4060997e+01,  8.9221001e+01,  5.8320000e+01],
#          [ 4.4060997e+01,  8.9221001e+01,  5.8320000e+01],
#          [ 4.5060997e+01,  9.0221001e+01,  5.9320000e+01],
#          ...,
#          [-9.1939003e+01, -4.3778999e+01, -4.8680000e+01],
#          [-8.8939003e+01, -6.0778999e+01, -4.5680000e+01],
#          [-9.5939003e+01, -6.7778999e+01, -5.2680000e+01]],
#
#         ...,
#
#         [[ 8.0609970e+00, -7.2778999e+01, -8.6680000e+01],
#          [ 1.1060997e+01, -6.8778999e+01, -8.4680000e+01],
#          [ 1.8060997e+01, -5.9778999e+01, -8.0680000e+01],
#          ...,
#          [-9.3900299e-01, -3.9778999e+01, -5.8680000e+01],
#          [-9.3900299e-01, -4.0778999e+01, -5.7680000e+01],
#          [-9.3900299e-01, -4.0778999e+01, -5.7680000e+01]],
#
#         [[ 1.0060997e+01, -7.0778999e+01, -8.4680000e+01],
#          [ 1.2060997e+01, -6.7778999e+01, -8.3680000e+01],
#          [ 1.8060997e+01, -5.9778999e+01, -8.0680000e+01],
#          ...,
#          [ 6.0997009e-02, -3.8778999e+01, -5.7680000e+01],
#          [ 6.0997009e-02, -3.9778999e+01, -5.6680000e+01],
#          [ 6.0997009e-02, -3.9778999e+01, -5.6680000e+01]],
#
#         [[ 1.1060997e+01, -6.9778999e+01, -8.3680000e+01],
#          [ 1.3060997e+01, -6.6778999e+01, -8.2680000e+01],
#          [ 1.8060997e+01, -5.9778999e+01, -8.0680000e+01],
#          ...,
#          [ 1.0609970e+00, -3.7778999e+01, -5.6680000e+01],
#          [ 1.0609970e+00, -3.8778999e+01, -5.5680000e+01],
#          [ 1.0609970e+00, -3.8778999e+01, -5.5680000e+01]]]],
#       dtype=float32)

# %%
model.predict(preprocessed_img).shape
# Out:
# 1/1 [==============================] - 1s 1s/step
# (1, 2048)

# %%
model.predict(preprocessed_img).flatten()
# Out:
# 1/1 [==============================] - 0s 177ms/step
# array([0.36031833, 0.7435787 , 0.        , ..., 1.1359036 , 0.5993019 ,
#        0.64565754], dtype=float32)

# %%
model.predict(preprocessed_img).flatten().shape
# Out:
# 1/1 [==============================] - 0s 165ms/step
# (2048,)

# %%
model.predict(preprocessed_img).flatten()/norm(model.predict(preprocessed_img).flatten())
# Out:
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 493ms/step
# array([0.0073089 , 0.01508318, 0.        , ..., 0.02304132, 0.01215658,
#        0.01309689], dtype=float32)

# %%
from numpy.linalg import norm
norm(model.predict(preprocessed_img).flatten())
# Out:
# 1/1 [==============================] - 0s 164ms/step
# 49.298542
